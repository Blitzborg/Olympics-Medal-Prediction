# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection

from sklearn.linear_model import LinearRegression
from sklearn.isotonic import IsotonicRegression
from sklearn.utils import check_random_state
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from random import random

#Importing the Dataset

data = pd.read_csv('newfile_summer.csv')
gold=pd.DataFrame(data[['Country','Year','Gold']])

'''
country=pd.DataFrame(data['Country'])
country_inst=pd.DataFrame(country['Country'].value_counts())
country_cnt = len(country_inst)

How to access variables:
print(country_inst.iloc[index].name) for name
print(country_inst.iloc[index][0]) for count
'''

country_record = []
index = 0
while (len(country_record)<9):
    year = []
    gold_cnt = []
    while (country_name in country_record):
        index += 1
        country_name = gold.iloc[index][0]    
    country_record.append(country_name)
    for i in range(len(gold)):
        if (gold.iloc[i][0] == country_name):
            year.append(gold.iloc[i][1])
            gold_cnt.append(gold.iloc[i][2])
    
    print(country_name)
    print(year)
    print(gold_cnt)


#Finding N
#append the data 
#We can display the number of times a country has participated in olympics
#Hence we noticed that some countries have not participated in every olympics
#close inner loop
#display the graph 
#close outer loop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8f2bb95ffc0b> in <module>
#      30     year = []
#      31     gold_cnt = []
# ---> 32     while (country_name in country_record):
#      33         index += 1
#      34         country_name = gold.iloc[index][0]
#
# NameError: name 'country_name' is not defined

# %%
'''


# AR example
from statsmodels.tsa.ar_model import AR
from random import random
# contrived dataset
data = []
# fit model
model = AR(data)
model_fit = model.fit()
# make prediction
yhat = model_fit.predict(len(data), len(data))
print(yhat)


x=pd.DataFrame(eg['x'])
y=pd.DataFrame(eg['y'])

n = 12
x = np.array([1968, 1972, 1976, 1984, 1988, 1992, 1996, 2000, 2004, 2008, 2012, 2016])
y = np.array([99, 69, 70, 186, 87, 89, 159, 130, 117, 127, 145, 139])

# #############################################################################
# Fit IsotonicRegression and LinearRegression models

ir = IsotonicRegression()

y_ = ir.fit_transform(x, y)

lr = LinearRegression()
lr.fit(x[:, np.newaxis], y)  # x needs to be 2d for LinearRegression

# #############################################################################
# Plot result

segments = [[[i, y[i]], [i, y_[i]]] for i in range(n)]
lc = LineCollection(segments, zorder=0)
lc.set_array(np.ones(len(y)))
lc.set_linewidths(np.full(n, 0.5))
p=(255,255,0)
fig = plt.figure()
plt.plot(x, y_, 'b.', markersize=12)
plt.plot(x, y_, 'y.-', markersize=12)
plt.plot(x, lr.predict(x[:, np.newaxis]), 'r-')
plt.gca().add_collection(lc)
plt.legend(('Data', 'Isotonic Fit', 'Linear Fit'), loc='lower right')
plt.title('Isotonic regression')


plt.show()
'''

# %%
# AR example
from statsmodels.tsa.ar_model import AR
from random import random


data = []


# fit model
model = AR(data)
model_fit = model.fit()


# make prediction
yhat = model_fit.predict(len(data), len(data))
print(yhat)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-a062c38e1dde> in <module>
#       9 # fit model
#      10 model = AR(data)
# ---> 11 model_fit = model.fit()
#      12
#      13
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/ar_model.py in fit(self, maxlag, method, ic, trend, transparams, start_params, solver, maxiter, full_output, disp, callback, **kwargs)
#     546         Y = endog[k_ar:, :]
#     547         # make lagged RHS
# --> 548         X = self._stackX(k_ar, trend)  # sets self.k_trend
#     549         k_trend = self.k_trend
#     550         self.exog_names = util.make_lag_names(self.endog_names, k_ar, k_trend)
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/ar_model.py in _stackX(self, k_ar, trend)
#     387         """
#     388         endog = self.endog
# --> 389         X = lagmat(endog, maxlag=k_ar, trim='both')
#     390         k_trend = util.get_trendorder(trend)
#     391         if k_trend:
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/tsatools.py in lagmat(x, maxlag, trim, original, use_pandas)
#     399         dropidx = nvar
#     400     if maxlag >= nobs:
# --> 401         raise ValueError("maxlag should be < nobs")
#     402     lm = np.zeros((nobs + maxlag, nvar * (maxlag + 1)))
#     403     for k in range(0, int(maxlag + 1)):
#
# ValueError: maxlag should be < nobs

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection

from sklearn.linear_model import LinearRegression
from sklearn.isotonic import IsotonicRegression
from sklearn.utils import check_random_state
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from random import random



n = 28
x = np.array([1896,1900,1904,1906,1908,1912,1920,1924,1928,1932,1936,1948,1952,1956,1960,1964,1968, 1972, 1976, 1984, 1988, 1992, 1996, 2000,2004,2008,2012,2016])
x1 = np.array([1916,1940,1944,1980])

y = np.array([11,30,128,12,34,46,111,97,47,81,51,87,83,61,81,95,99,69,70,186,87,89,159,130,117,127,145,139])

# #############################################################################
# Fit IsotonicRegression and LinearRegression models

ir = IsotonicRegression()

y_ = ir.fit_transform(x, y)

lr = LinearRegression()
lr.fit(x[:, np.newaxis], y)  # x needs to be 2d for LinearRegression


y1=ir.predict(x1)
print(y1)


# #############################################################################
# Plot result

segments = [[[i, y[i]], [i, y_[i]]] for i in range(n)]
lc = LineCollection(segments, zorder=0)
lc.set_array(np.ones(len(y)))
lc.set_linewidths(np.full(n, 0.5))


fig = plt.figure()

plt.plot(x, y, 'b.', markersize=12)
plt.plot(x, y_, 'y.-', markersize=12)
plt.plot(x, lr.predict(x[:, np.newaxis]), 'r-')
plt.gca().add_collection(lc)
plt.legend(('Data', 'Isotonic Fit', 'Linear Fit'), loc='lower right')
plt.title('Isotonic regression')

plt.show()

# %%
print(y1   )
